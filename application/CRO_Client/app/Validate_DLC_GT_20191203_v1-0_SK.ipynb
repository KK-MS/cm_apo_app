# %%
from ERGPY import *
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Import CarMaker Parameters

# %%
ergpy = ERGPY()
quantities = ergpy.parse('C:\\Users\\ll_stsekeid\\Desktop\\Basti_Projekt\\app\\B308_W_123429.erg')

# %%
for q in quantities:
    print(q.name)
# Out:
# Car.Distance
# Car.Road.GCS.Lat
# Car.Road.GCS.Long
# Time
# Car.Road.GCS.Elev
# Car.Road.Lane.Act.Width
# Car.Road.Path.DevDist
# Sensor.TSign.TS00.0.ds
# Sensor.TSign.TS00.0.ds.x
# Sensor.TSign.TS00.0.ds.y
# Sensor.TSign.TS00.0.ds.z
# Sensor.TSign.TS00.TimeStamp
# Sensor.TSign.TS00.0.Main.val0
# Sensor.TSign.TS00.0.Main.val1
# Sensor.TSign.TS00.0.ObjId
# Sensor.TSign.TS00.nSign

# %%
CM_DLC = ergpy.getSingleQuantityValues('Car.Road.Path.DevDist')

# %%
dfcm = pd.DataFrame()
dfcm['cm_d2l'] = CM_DLC

# %%
dfcm.index
# Out:
# RangeIndex(start=0, stop=721, step=1)

# %%
#Velocity 3.6 km/h & 1 Hz Frequenz
# %matplotlib inline
plt.plot(dfcm.index,dfcm.cm_d2l)
plt.ylim(-2.11,2.11)
plt.show()

# %%
len(CM_DLC)
# Out:
# 721

# %% [markdown]
# # Import GT Parametes

# %%
df = pd.read_csv('Eval6.csv',sep=',')
df.head()
# Out:
#    Unnamed: 0       d2l        lon        lat
# 0           0  0.246791  10.206625  47.560869
# 1           1  0.247158  10.206626  47.560869
# 2           2  0.245947  10.206624  47.560869
# 3           3  0.236983  10.206612  47.560871
# 4           4  0.222602  10.206589  47.560875

# %%
len(df.d2l)

#df['d2l'] = [df.d2l[i]*-1 for i in range(len(df))]
# Out:
# 780

# %%
import numpy as np

#for i in range(len(df)):
    
#    if df.d2l[i] < -10:
        
#        df.d2l[i] = np.NaN
        
df['d2l'] = [df.d2l[i] if df.d2l[i] > -10 else np.NaN for i in range(len(df)) ]
df['d2l'] = [df.d2l[i]*-1 for i in range(len(df))]

# %%
# %matplotlib inline
plt.plot(df.index,df.d2l)
plt.ylim(-2.11,2.11)
plt.show()

# %%
# Ref Point CM correction
